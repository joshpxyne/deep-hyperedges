# %%
import pandas as pd
import numpy as np
import time as time
import pickle
from sklearn.utils import shuffle
import seaborn as sns
import matplotlib.pyplot as plt
import random
import networkx as nx
from sklearn.metrics import classification_report

# %%
datadir = "data/cora"
max_groupsize = 169
min_groupsize = 2
num_negatives = 4000
num_categories = 7

# %%
G = nx.read_edgelist(datadir+"/cora.edges", nodetype=str) # must be in edgelist (node1 node2\n) format

# %%
classes = {}
with open(datadir+"/cora.node_labels") as f:
    content = f.readlines()
    
for line in content:
    keyval = line.split(",")
    classes[str(keyval[0])] = str(keyval[1][:1])

# %%
hyperedges = {}
nodes = G.nodes
max_size = 0
min_size = 100000
for node in nodes:
    neighborhood = list(G.neighbors(node))
    if len(neighborhood)+1 <= max_groupsize and len(neighborhood)+1 >= min_groupsize:
        hyperedges[node] = {}
        hyperedges[node]["members"] = []
        hyperedges[node]["members"].append(node)
        hyperedges[node]["category"] = classes[node]
        for neighbor in neighborhood:
            hyperedges[node]["members"].append(neighbor)
    if len(neighborhood)+1 < min_size:
        min_size = len(neighborhood)+1
    if len(neighborhood) > max_size:
        max_size = len(neighborhood)+1
print(min_size, max_size)
print(len(hyperedges))
# Out:
# 2 169
# 2708

# %%
cat_amounts = {}
cat_names = {"1":"Neural Networks","2":"Case Based","3":"Reinforcement Learning", "4":"Probabilistic Methods", "5":"Genetic Algorithms", "6":"Rule Learning", "7": "Theory"}

for h in hyperedges:
    if cat_names[str(hyperedges[h]["category"])] not in cat_amounts:
        cat_amounts[cat_names[str(hyperedges[h]["category"])]]=1
    else:
        cat_amounts[cat_names[str(hyperedges[h]["category"])]]+=1


pd_df = pd.DataFrame(list(cat_amounts.items()))
pd_df.columns =["Dim","Count"]
# sort df by Count column
pd_df = pd_df.sort_values(['Count']).reset_index(drop=True)

plt.figure(figsize=(12,8))
# plot barh chart with index as x values
ax = sns.barplot(pd_df.index, pd_df.Count)
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
ax.set(xlabel="Dim", ylabel='Count')
# add proper Dim values as x labels
ax.set_xticklabels(pd_df.Dim)
for item in ax.get_xticklabels(): item.set_rotation(90)
for i, v in enumerate(pd_df["Count"].iteritems()):        
    ax.text(i ,v[1], "{:,}".format(v[1]), color='m', va ='bottom', rotation=45)
plt.tight_layout()
plt.show()

# %%
vertexMemberships = {}
for h_index in hyperedges:
    hyperedge = hyperedges[h_index]
    authors = hyperedge["members"]
    for author in authors:
        if author in vertexMemberships:
            vertexMemberships[author].append(h_index)
        else:
            authorMembershipList = []
            authorMembershipList.append(h_index)
            vertexMemberships[author] = authorMembershipList

# %%
print(len(hyperedges))
print(len(vertexMemberships))
with open(datadir+'/hyperedges.p', 'wb') as fp:
    pickle.dump(hyperedges, fp)
with open(datadir+'/vertexMemberships.p', 'wb') as fp:
    pickle.dump(vertexMemberships, fp)
# Out:
# 2708
# 2708

# %%
from HypergraphRandomWalks import SubsampleAndTraverse

walksSAT = SubsampleAndTraverse(length=50, 
                                   num_walks=50, 
                                   hyperedges=hyperedges, 
                                   vertexMemberships=vertexMemberships,
                                   p_traverse_method="inverse",
                                   p_traverse=0.15, 
                                   p_traverse_initial=0.1)

# %%
from HypergraphRandomWalks import TraverseAndSelect

walksTAS = TraverseAndSelect(length=50, 
                               num_walks=50, 
                               hyperedges=hyperedges, 
                               vertexMemberships=vertexMemberships,
                               p_select_method="inverse",
                               p_select=0.15, 
                               p_select_initial=0.1)

# %%
with open(datadir+'/walksSAT.p', 'wb') as fp:
    pickle.dump(walksSAT, fp)

with open(datadir+'/walksTAS.p', 'wb') as fp:
    pickle.dump(walksTAS, fp)

# %%
from Embeddings import EmbedWord2Vec

vertex_embedding_dimension = 16
hyperedge_embedding_dimension = 128

vertex_ids, vertex_embeddings = EmbedWord2Vec(walks=walksSAT,dimension=vertex_embedding_dimension)
print("Vertex embeddings finished.")
hyperedge_ids, hyperedge_embeddings = EmbedWord2Vec(walks=walksTAS,dimension=hyperedge_embedding_dimension)
print("Hyperedge embeddings finished.")
# Out:
# Creating embeddings.
# Embedding generation runtime:  168.0423619747162
# Vertex embeddings finished.
# Creating embeddings.
# Embedding generation runtime:  241.34736514091492
# Hyperedge embeddings finished.

# %%
print(len(vertex_embeddings))
with open(datadir+'/vertex_embeddings_'+str(max_groupsize)+'.p', 'wb') as fp:
    pickle.dump(vertex_embeddings, fp)
print(len(hyperedge_embeddings))
with open(datadir+'/hyperedge_embeddings_'+str(max_groupsize)+'.p', 'wb') as fp:
    pickle.dump(hyperedge_embeddings, fp)
# Out:
# 2708
# 2708

# %%
import matplotlib.cm as cm
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

def visualizeTSNE(embeddings,obj,with_labels=None,ids=None):
    targets = None
    transform = TSNE
    num_cats=7
    trans = transform(n_components=2)
    embeddings_2d = trans.fit_transform(embeddings)

    alpha = 0.7
    plt.figure(figsize=(7,7))
    plt.axes().set(aspect="equal")
    
    if with_labels:
        targets = [int(with_labels[identifier]['category'])-1 for identifier in ids]
        cmap = cm.rainbow(np.linspace(0.0, 1.0, num_cats))
        colors = cmap[targets]
        
        plt.scatter(embeddings_2d[:,0], 
                    embeddings_2d[:,1], 
                    cmap="jet", c=colors, alpha=alpha)
    else:
        plt.scatter(embeddings_2d[:,0], 
                    embeddings_2d[:,1], 
                    cmap="jet", alpha=alpha)
    
    plt.title('TSNE visualization of '+obj+' embeddings in the hypergraph.'.format(transform.__name__))
    plt.show()
    return targets
targets = visualizeTSNE(vertex_embeddings,"vertex")
targets = visualizeTSNE(hyperedge_embeddings,"hyperedge",hyperedges,hyperedge_ids)

# %%
def getTrainingData():
    i = 0
    lists = []
    labels = []
    maxi = 0
    for h in hyperedges:
        
        vertex_embedding_list = []
        hyperedge = hyperedges[h]
        for vertex in hyperedge["members"]:
            i+=1
            if i%100000==0:
                print(i)
            try: # Good ol' nondeterminism
                vertex_embedding_list.append(vertex_embeddings[vertex_ids.index(vertex)].tolist())
            except:
                print("Missed one: ",vertex)
        lists.append({"v":vertex_embedding_list,"h":hyperedge_embeddings[hyperedge_ids.index(h)].tolist()})
        label = np.zeros((num_categories,))
        label[int(hyperedge["category"])-1] = 1
        labels.append(label)
    X_unshuffled = []
    
    for hlist in lists:
        np_vertex_embeddings = np.asarray(hlist["v"])
        x = np.zeros((hyperedge_embedding_dimension + vertex_embedding_dimension*max_groupsize,))
        i = 0
        x[:hyperedge_embedding_dimension] = hlist["h"]
        
        for embedding in np_vertex_embeddings:
            x[hyperedge_embedding_dimension + i*embedding.shape[0]:hyperedge_embedding_dimension + (i+1)*embedding.shape[0]] = embedding
            i+=1
        X_unshuffled.append(x)
    labels = np.asarray(labels)
    X_arr, Y_arr = shuffle(X_unshuffled, labels)
    X = np.asarray(X_arr)
    Y = np.asarray(Y_arr)
    return X, Y

X, Y = getTrainingData()

print(X.shape)
print(Y.shape)

# np.save(datadir+'/X_hyperedge_'+str(max_groupsize)+'.npy', X)
# np.save(datadir+'/Y_hyperedge_'+str(max_groupsize)+'.npy', Y)

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.9, test_size=0.1)
# Out:
# (2708, 2832)
# (2708, 7)

# %%
# %load_ext autoreload
# %autoreload 2

from Models import DeepHyperedges
from keras.callbacks import ModelCheckpoint, TensorBoard
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

dataset_name = "cora"
batch_size = 128
num_epochs = 50

deephyperedges_model = DeepHyperedges(vertex_embedding_dimension=vertex_embedding_dimension,
                                     hyperedge_embedding_dimension=hyperedge_embedding_dimension,
                                     max_hyperedge_size=max_groupsize,
                                     num_outputs=num_categories,
                                     dataset_name=dataset_name)
plot_model(deephyperedges_model, to_file='images/'+dataset_name+'_deephyperedges_model.png')
checkpointer = ModelCheckpoint(filepath='weights/'+dataset_name+'/deephyperedges_weights.hdf5', verbose=0, save_best_only=True)
tbCallBack = TensorBoard(log_dir='logs/'+dataset_name+'/deephyperedges_logs', histogram_freq=0, batch_size=batch_size, write_graph=True, write_grads=True, write_images=True, update_freq='batch')

history = deephyperedges_model.fit(X_train, Y_train, epochs=num_epochs, batch_size=batch_size,
        shuffle=True, validation_split=0.1,
        callbacks=[checkpointer,tbCallBack], verbose=1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Train on 2193 samples, validate on 244 samples
# Epoch 1/50
# 2193/2193 [==============================] - 12s 5ms/step - loss: 1.8235 - mean_absolute_error: 0.2296 - categorical_accuracy: 0.2695 - f1_m: 0.0444 - val_loss: 1.6229 - val_mean_absolute_error: 0.2197 - val_categorical_accuracy: 0.4344 - val_f1_m: 0.0243
# Epoch 2/50
# 2193/2193 [==============================] - 1s 575us/step - loss: 1.4194 - mean_absolute_error: 0.2037 - categorical_accuracy: 0.5308 - f1_m: 0.1849 - val_loss: 1.2783 - val_mean_absolute_error: 0.1860 - val_categorical_accuracy: 0.5533 - val_f1_m: 0.4087
# Epoch 3/50
# 2193/2193 [==============================] - 1s 575us/step - loss: 1.1303 - mean_absolute_error: 0.1726 - categorical_accuracy: 0.6598 - f1_m: 0.4802 - val_loss: 1.0312 - val_mean_absolute_error: 0.1586 - val_categorical_accuracy: 0.6926 - val_f1_m: 0.5567
# Epoch 4/50
# 2193/2193 [==============================] - 1s 558us/step - loss: 0.9334 - mean_absolute_error: 0.1463 - categorical_accuracy: 0.7319 - f1_m: 0.6291 - val_loss: 0.8952 - val_mean_absolute_error: 0.1358 - val_categorical_accuracy: 0.7090 - val_f1_m: 0.6847
# Epoch 5/50
# 2193/2193 [==============================] - 1s 558us/step - loss: 0.8201 - mean_absolute_error: 0.1265 - categorical_accuracy: 0.7583 - f1_m: 0.7045 - val_loss: 0.7928 - val_mean_absolute_error: 0.1211 - val_categorical_accuracy: 0.7541 - val_f1_m: 0.7371
# Epoch 6/50
# 2193/2193 [==============================] - 1s 555us/step - loss: 0.7494 - mean_absolute_error: 0.1143 - categorical_accuracy: 0.7697 - f1_m: 0.7389 - val_loss: 0.7367 - val_mean_absolute_error: 0.1114 - val_categorical_accuracy: 0.7705 - val_f1_m: 0.7694
# Epoch 7/50
# 2193/2193 [==============================] - 1s 555us/step - loss: 0.7023 - mean_absolute_error: 0.1065 - categorical_accuracy: 0.7875 - f1_m: 0.7526 - val_loss: 0.7029 - val_mean_absolute_error: 0.1052 - val_categorical_accuracy: 0.7787 - val_f1_m: 0.7871
# Epoch 8/50
# 2193/2193 [==============================] - 1s 557us/step - loss: 0.6646 - mean_absolute_error: 0.1002 - categorical_accuracy: 0.7966 - f1_m: 0.7805 - val_loss: 0.6748 - val_mean_absolute_error: 0.0997 - val_categorical_accuracy: 0.7828 - val_f1_m: 0.7864
# Epoch 9/50
# 2193/2193 [==============================] - 1s 543us/step - loss: 0.6345 - mean_absolute_error: 0.0956 - categorical_accuracy: 0.8053 - f1_m: 0.7943 - val_loss: 0.6580 - val_mean_absolute_error: 0.0962 - val_categorical_accuracy: 0.7828 - val_f1_m: 0.7940
# Epoch 10/50
# 2193/2193 [==============================] - 1s 536us/step - loss: 0.6118 - mean_absolute_error: 0.0920 - categorical_accuracy: 0.8126 - f1_m: 0.8046 - val_loss: 0.6456 - val_mean_absolute_error: 0.0949 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.7950
# Epoch 11/50
# 2193/2193 [==============================] - 1s 534us/step - loss: 0.5919 - mean_absolute_error: 0.0894 - categorical_accuracy: 0.8153 - f1_m: 0.8085 - val_loss: 0.6320 - val_mean_absolute_error: 0.0921 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.8091
# Epoch 12/50
# 2193/2193 [==============================] - 1s 537us/step - loss: 0.5707 - mean_absolute_error: 0.0863 - categorical_accuracy: 0.8263 - f1_m: 0.8158 - val_loss: 0.6317 - val_mean_absolute_error: 0.0912 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.8034
# Epoch 13/50
# 2193/2193 [==============================] - 1s 533us/step - loss: 0.5609 - mean_absolute_error: 0.0851 - categorical_accuracy: 0.8267 - f1_m: 0.8172 - val_loss: 0.6105 - val_mean_absolute_error: 0.0880 - val_categorical_accuracy: 0.7910 - val_f1_m: 0.7946
# Epoch 14/50
# 2193/2193 [==============================] - 1s 544us/step - loss: 0.5415 - mean_absolute_error: 0.0826 - categorical_accuracy: 0.8313 - f1_m: 0.8267 - val_loss: 0.6070 - val_mean_absolute_error: 0.0872 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.8044
# Epoch 15/50
# 2193/2193 [==============================] - 1s 527us/step - loss: 0.5287 - mean_absolute_error: 0.0804 - categorical_accuracy: 0.8381 - f1_m: 0.8302 - val_loss: 0.5939 - val_mean_absolute_error: 0.0856 - val_categorical_accuracy: 0.8033 - val_f1_m: 0.8033
# Epoch 16/50
# 2193/2193 [==============================] - 1s 519us/step - loss: 0.5151 - mean_absolute_error: 0.0785 - categorical_accuracy: 0.8368 - f1_m: 0.8315 - val_loss: 0.6029 - val_mean_absolute_error: 0.0858 - val_categorical_accuracy: 0.8115 - val_f1_m: 0.8082
# Epoch 17/50
# 2193/2193 [==============================] - 1s 520us/step - loss: 0.5059 - mean_absolute_error: 0.0777 - categorical_accuracy: 0.8450 - f1_m: 0.8386 - val_loss: 0.5911 - val_mean_absolute_error: 0.0844 - val_categorical_accuracy: 0.8074 - val_f1_m: 0.8061
# Epoch 18/50
# 2193/2193 [==============================] - 1s 534us/step - loss: 0.4907 - mean_absolute_error: 0.0758 - categorical_accuracy: 0.8477 - f1_m: 0.8445 - val_loss: 0.5916 - val_mean_absolute_error: 0.0831 - val_categorical_accuracy: 0.8033 - val_f1_m: 0.8049
# Epoch 19/50
# 2193/2193 [==============================] - 1s 522us/step - loss: 0.4821 - mean_absolute_error: 0.0740 - categorical_accuracy: 0.8491 - f1_m: 0.8461 - val_loss: 0.5836 - val_mean_absolute_error: 0.0815 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8123
# Epoch 20/50
# 2193/2193 [==============================] - 1s 556us/step - loss: 0.4732 - mean_absolute_error: 0.0727 - categorical_accuracy: 0.8559 - f1_m: 0.8493 - val_loss: 0.5881 - val_mean_absolute_error: 0.0815 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8176
# Epoch 21/50
# 2193/2193 [==============================] - 1s 540us/step - loss: 0.4630 - mean_absolute_error: 0.0716 - categorical_accuracy: 0.8573 - f1_m: 0.8509 - val_loss: 0.5874 - val_mean_absolute_error: 0.0829 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.8123
# Epoch 22/50
# 2193/2193 [==============================] - 1s 535us/step - loss: 0.4582 - mean_absolute_error: 0.0716 - categorical_accuracy: 0.8573 - f1_m: 0.8538 - val_loss: 0.5730 - val_mean_absolute_error: 0.0809 - val_categorical_accuracy: 0.8115 - val_f1_m: 0.8187
# Epoch 23/50
# 2193/2193 [==============================] - 1s 540us/step - loss: 0.4475 - mean_absolute_error: 0.0706 - categorical_accuracy: 0.8596 - f1_m: 0.8551 - val_loss: 0.5758 - val_mean_absolute_error: 0.0802 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8082
# Epoch 24/50
# 2193/2193 [==============================] - 1s 531us/step - loss: 0.4393 - mean_absolute_error: 0.0689 - categorical_accuracy: 0.8646 - f1_m: 0.8611 - val_loss: 0.5721 - val_mean_absolute_error: 0.0793 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8020
# Epoch 25/50
# 2193/2193 [==============================] - 1s 554us/step - loss: 0.4299 - mean_absolute_error: 0.0674 - categorical_accuracy: 0.8650 - f1_m: 0.8640 - val_loss: 0.5749 - val_mean_absolute_error: 0.0800 - val_categorical_accuracy: 0.8115 - val_f1_m: 0.8180
# Epoch 26/50
# 2193/2193 [==============================] - 1s 546us/step - loss: 0.4256 - mean_absolute_error: 0.0673 - categorical_accuracy: 0.8673 - f1_m: 0.8638 - val_loss: 0.5637 - val_mean_absolute_error: 0.0780 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8131
# Epoch 27/50
# 2193/2193 [==============================] - 1s 544us/step - loss: 0.4175 - mean_absolute_error: 0.0661 - categorical_accuracy: 0.8719 - f1_m: 0.8683 - val_loss: 0.5742 - val_mean_absolute_error: 0.0781 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8088
# Epoch 28/50
# 2193/2193 [==============================] - 1s 574us/step - loss: 0.4089 - mean_absolute_error: 0.0647 - categorical_accuracy: 0.8760 - f1_m: 0.8719 - val_loss: 0.5618 - val_mean_absolute_error: 0.0769 - val_categorical_accuracy: 0.8115 - val_f1_m: 0.8150
# Epoch 29/50
# 2193/2193 [==============================] - 1s 549us/step - loss: 0.4036 - mean_absolute_error: 0.0640 - categorical_accuracy: 0.8796 - f1_m: 0.8755 - val_loss: 0.5556 - val_mean_absolute_error: 0.0762 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8097
# Epoch 30/50
# 2193/2193 [==============================] - 1s 559us/step - loss: 0.3956 - mean_absolute_error: 0.0632 - categorical_accuracy: 0.8792 - f1_m: 0.8743 - val_loss: 0.5639 - val_mean_absolute_error: 0.0769 - val_categorical_accuracy: 0.8115 - val_f1_m: 0.8097
# Epoch 31/50
# 2193/2193 [==============================] - 1s 557us/step - loss: 0.3895 - mean_absolute_error: 0.0624 - categorical_accuracy: 0.8810 - f1_m: 0.8783 - val_loss: 0.5754 - val_mean_absolute_error: 0.0766 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8144
# Epoch 32/50
# 2193/2193 [==============================] - 1s 548us/step - loss: 0.3855 - mean_absolute_error: 0.0618 - categorical_accuracy: 0.8787 - f1_m: 0.8785 - val_loss: 0.5662 - val_mean_absolute_error: 0.0760 - val_categorical_accuracy: 0.8033 - val_f1_m: 0.8067
# Epoch 33/50
# 2193/2193 [==============================] - 1s 542us/step - loss: 0.3761 - mean_absolute_error: 0.0603 - categorical_accuracy: 0.8851 - f1_m: 0.8827 - val_loss: 0.5794 - val_mean_absolute_error: 0.0761 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8143
# Epoch 34/50
# 2193/2193 [==============================] - 1s 546us/step - loss: 0.3679 - mean_absolute_error: 0.0597 - categorical_accuracy: 0.8915 - f1_m: 0.8919 - val_loss: 0.6053 - val_mean_absolute_error: 0.0764 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8093
# Epoch 35/50
# 2193/2193 [==============================] - 1s 563us/step - loss: 0.3643 - mean_absolute_error: 0.0585 - categorical_accuracy: 0.8883 - f1_m: 0.8882 - val_loss: 0.5726 - val_mean_absolute_error: 0.0746 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8186
# Epoch 36/50
# 2193/2193 [==============================] - 1s 536us/step - loss: 0.3590 - mean_absolute_error: 0.0581 - categorical_accuracy: 0.8896 - f1_m: 0.8860 - val_loss: 0.5713 - val_mean_absolute_error: 0.0746 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8167
# Epoch 37/50
# 2193/2193 [==============================] - 1s 539us/step - loss: 0.3503 - mean_absolute_error: 0.0565 - categorical_accuracy: 0.9006 - f1_m: 0.8940 - val_loss: 0.5768 - val_mean_absolute_error: 0.0742 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8193
# Epoch 38/50
# 2193/2193 [==============================] - 1s 536us/step - loss: 0.3450 - mean_absolute_error: 0.0563 - categorical_accuracy: 0.8988 - f1_m: 0.8965 - val_loss: 0.5635 - val_mean_absolute_error: 0.0732 - val_categorical_accuracy: 0.8074 - val_f1_m: 0.8148
# Epoch 39/50
# 2193/2193 [==============================] - 1s 537us/step - loss: 0.3399 - mean_absolute_error: 0.0552 - categorical_accuracy: 0.8979 - f1_m: 0.8972 - val_loss: 0.5681 - val_mean_absolute_error: 0.0732 - val_categorical_accuracy: 0.8320 - val_f1_m: 0.8278
# Epoch 40/50
# 2193/2193 [==============================] - 1s 534us/step - loss: 0.3323 - mean_absolute_error: 0.0545 - categorical_accuracy: 0.9052 - f1_m: 0.9029 - val_loss: 0.5737 - val_mean_absolute_error: 0.0733 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8235
# Epoch 41/50
# 2193/2193 [==============================] - 1s 534us/step - loss: 0.3259 - mean_absolute_error: 0.0536 - categorical_accuracy: 0.9056 - f1_m: 0.9058 - val_loss: 0.5844 - val_mean_absolute_error: 0.0731 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8210
# Epoch 42/50
# 2193/2193 [==============================] - 1s 527us/step - loss: 0.3225 - mean_absolute_error: 0.0530 - categorical_accuracy: 0.9088 - f1_m: 0.9057 - val_loss: 0.5683 - val_mean_absolute_error: 0.0723 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8287
# Epoch 43/50
# 2193/2193 [==============================] - 1s 530us/step - loss: 0.3144 - mean_absolute_error: 0.0519 - categorical_accuracy: 0.9115 - f1_m: 0.9095 - val_loss: 0.5620 - val_mean_absolute_error: 0.0719 - val_categorical_accuracy: 0.8279 - val_f1_m: 0.8235
# Epoch 44/50
# 2193/2193 [==============================] - 1s 532us/step - loss: 0.3062 - mean_absolute_error: 0.0508 - categorical_accuracy: 0.9166 - f1_m: 0.9130 - val_loss: 0.5533 - val_mean_absolute_error: 0.0712 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8207
# Epoch 45/50
# 2193/2193 [==============================] - 1s 552us/step - loss: 0.3032 - mean_absolute_error: 0.0503 - categorical_accuracy: 0.9152 - f1_m: 0.9119 - val_loss: 0.5621 - val_mean_absolute_error: 0.0710 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8296
# Epoch 46/50
# 2193/2193 [==============================] - 1s 535us/step - loss: 0.2958 - mean_absolute_error: 0.0498 - categorical_accuracy: 0.9152 - f1_m: 0.9157 - val_loss: 0.5801 - val_mean_absolute_error: 0.0710 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8259
# Epoch 47/50
# 2193/2193 [==============================] - 1s 546us/step - loss: 0.2933 - mean_absolute_error: 0.0490 - categorical_accuracy: 0.9188 - f1_m: 0.9153 - val_loss: 0.5574 - val_mean_absolute_error: 0.0708 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8295
# Epoch 48/50
# 2193/2193 [==============================] - 1s 535us/step - loss: 0.2865 - mean_absolute_error: 0.0484 - categorical_accuracy: 0.9193 - f1_m: 0.9159 - val_loss: 0.5529 - val_mean_absolute_error: 0.0706 - val_categorical_accuracy: 0.8074 - val_f1_m: 0.8201
# Epoch 49/50
# 2193/2193 [==============================] - 1s 533us/step - loss: 0.2828 - mean_absolute_error: 0.0482 - categorical_accuracy: 0.9170 - f1_m: 0.9166 - val_loss: 0.5820 - val_mean_absolute_error: 0.0700 - val_categorical_accuracy: 0.8197 - val_f1_m: 0.8251
# Epoch 50/50
# 2193/2193 [==============================] - 1s 540us/step - loss: 0.2778 - mean_absolute_error: 0.0467 - categorical_accuracy: 0.9216 - f1_m: 0.9212 - val_loss: 0.5516 - val_mean_absolute_error: 0.0701 - val_categorical_accuracy: 0.8238 - val_f1_m: 0.8303

# %%
from sklearn.metrics import classification_report, accuracy_score

target_names = ["Neural Networks","Case Based","Reinforcement Learning","Probabilistic Methods","Genetic Algorithms","Rule Learning","Theory"]

y_pred = deephyperedges_model.predict(X_test, batch_size=16, verbose=1)
finals_pred = []
finals_test = []
for p in y_pred:
    m = 0
    ind = 0
    final = 0
    for i in p:
        if i>m:
            m=i
            final=ind
        ind+=1
    finals_pred.append(final)

for i in Y_test:
    ind=0
    for j in i:
        if j==1:
            finals_test.append(ind)
        ind+=1
            
print(classification_report(finals_test, finals_pred, target_names=target_names))
print(accuracy_score(finals_test, finals_pred))
# Out:
# 271/271 [==============================] - 6s 23ms/step
#                         precision    recall  f1-score   support
#
#        Neural Networks       0.81      0.73      0.77        30
#             Case Based       0.82      0.97      0.89        34
# Reinforcement Learning       0.87      0.84      0.85        92
#  Probabilistic Methods       0.85      0.87      0.86        38
#     Genetic Algorithms       0.83      0.76      0.79        25
#          Rule Learning       0.71      0.81      0.76        21
#                 Theory       0.76      0.71      0.73        31
#
#              micro avg       0.82      0.82      0.82       271
#              macro avg       0.81      0.81      0.81       271
#           weighted avg       0.82      0.82      0.82       271
#
# 0.8228782287822878

# %%
def getMLPTrainingData():
    i = 0
    lists = []
    labels = []
    maxi = 0
    for h in hyperedges:
        vertex_embedding_list = []
        hyperedge = hyperedges[h]
        lists.append({"h":hyperedge_embeddings[hyperedge_ids.index(h)].tolist()})
        label = np.zeros((num_categories,))
        label[int(hyperedge["category"])-1] = 1
        labels.append(label)
    X_unshuffled = []
    for hlist in lists:
        x = np.zeros((hyperedge_embedding_dimension,))
        x[:hyperedge_embedding_dimension] = hlist["h"]
        X_unshuffled.append(x)
    labels = np.asarray(labels)
    X_arr, Y_arr = shuffle(X_unshuffled, labels)
    X_MLP = np.asarray(X_arr)
    Y_MLP = np.asarray(Y_arr)
    return X_MLP, Y_MLP

X_MLP, Y_MLP = getMLPTrainingData()
# np.save(datadir+'/X_MLP_'+str(max_groupsize)+'.npy', X_MLP)
# np.save(datadir+'/Y_MLP_'+str(max_groupsize)+'.npy', Y_MLP)

from sklearn.model_selection import train_test_split
X_MLP_train, X_MLP_test, Y_MLP_train, Y_MLP_test = train_test_split(X_MLP, Y_MLP, train_size=0.9, test_size=0.1)

# %%
# %autoreload 2
from Models import MLP
dataset_name = "cora"
batch_size = 128
num_epochs = 10

MLP_model = MLP(input_dimension=hyperedge_embedding_dimension,
                 num_outputs=num_categories,
                 dataset_name=dataset_name)
plot_model(MLP_model, to_file='images/'+dataset_name+'_MLP_model.png')
checkpointer = ModelCheckpoint(filepath='weights/'+dataset_name+'/MLP_weights.hdf5', verbose=0, save_best_only=True)
tbCallBack = TensorBoard(log_dir='logs/'+dataset_name+'/MLP_logs', histogram_freq=0, batch_size=batch_size, write_graph=True, write_grads=True, write_images=True, update_freq='batch')

history = MLP_model.fit(X_MLP_train, Y_MLP_train, epochs=num_epochs, batch_size=batch_size,
        shuffle=True, validation_split=0.1,
        callbacks=[checkpointer,tbCallBack], verbose=1)
# Out:
# Train on 2193 samples, validate on 244 samples
# Epoch 1/10
# 2193/2193 [==============================] - 5s 3ms/step - loss: 1.7313 - mean_absolute_error: 0.2265 - categorical_accuracy: 0.3388 - f1_m: 0.0658 - val_loss: 1.5432 - val_mean_absolute_error: 0.2130 - val_categorical_accuracy: 0.4139 - val_f1_m: 0.1412
# Epoch 2/10
# 2193/2193 [==============================] - 0s 199us/step - loss: 1.3610 - mean_absolute_error: 0.1968 - categorical_accuracy: 0.5750 - f1_m: 0.2578 - val_loss: 1.2247 - val_mean_absolute_error: 0.1854 - val_categorical_accuracy: 0.6393 - val_f1_m: 0.3696
# Epoch 3/10
# 2193/2193 [==============================] - 0s 191us/step - loss: 1.0753 - mean_absolute_error: 0.1657 - categorical_accuracy: 0.6963 - f1_m: 0.5213 - val_loss: 1.0167 - val_mean_absolute_error: 0.1598 - val_categorical_accuracy: 0.7008 - val_f1_m: 0.5516
# Epoch 4/10
# 2193/2193 [==============================] - 0s 193us/step - loss: 0.9004 - mean_absolute_error: 0.1418 - categorical_accuracy: 0.7323 - f1_m: 0.6624 - val_loss: 0.9026 - val_mean_absolute_error: 0.1388 - val_categorical_accuracy: 0.7131 - val_f1_m: 0.6550
# Epoch 5/10
# 2193/2193 [==============================] - 0s 193us/step - loss: 0.7940 - mean_absolute_error: 0.1232 - categorical_accuracy: 0.7565 - f1_m: 0.7232 - val_loss: 0.8308 - val_mean_absolute_error: 0.1261 - val_categorical_accuracy: 0.7049 - val_f1_m: 0.6989
# Epoch 6/10
# 2193/2193 [==============================] - 0s 184us/step - loss: 0.7311 - mean_absolute_error: 0.1130 - categorical_accuracy: 0.7766 - f1_m: 0.7428 - val_loss: 0.7965 - val_mean_absolute_error: 0.1184 - val_categorical_accuracy: 0.7418 - val_f1_m: 0.7190
# Epoch 7/10
# 2193/2193 [==============================] - 0s 188us/step - loss: 0.6881 - mean_absolute_error: 0.1054 - categorical_accuracy: 0.7788 - f1_m: 0.7613 - val_loss: 0.7702 - val_mean_absolute_error: 0.1126 - val_categorical_accuracy: 0.7295 - val_f1_m: 0.7320
# Epoch 8/10
# 2193/2193 [==============================] - 0s 186us/step - loss: 0.6546 - mean_absolute_error: 0.0990 - categorical_accuracy: 0.7953 - f1_m: 0.7737 - val_loss: 0.7510 - val_mean_absolute_error: 0.1091 - val_categorical_accuracy: 0.7377 - val_f1_m: 0.7383
# Epoch 9/10
# 2193/2193 [==============================] - 0s 177us/step - loss: 0.6266 - mean_absolute_error: 0.0954 - categorical_accuracy: 0.8035 - f1_m: 0.7895 - val_loss: 0.7374 - val_mean_absolute_error: 0.1055 - val_categorical_accuracy: 0.7377 - val_f1_m: 0.7356
# Epoch 10/10
# 2193/2193 [==============================] - 0s 176us/step - loss: 0.6081 - mean_absolute_error: 0.0915 - categorical_accuracy: 0.8103 - f1_m: 0.7961 - val_loss: 0.7264 - val_mean_absolute_error: 0.1039 - val_categorical_accuracy: 0.7746 - val_f1_m: 0.7432

# %%
Y_pred_MLP = MLP_model.predict(X_MLP_test, batch_size=16, verbose=1)
finals_pred_MLP = []
finals_test_MLP = []
for p in Y_pred_MLP:
    m = 0
    ind = 0
    final = 0
    for i in p:
        if i>m:
            m=i
            final=ind
        ind+=1
    finals_pred_MLP.append(final)

for i in Y_MLP_test:
    ind=0
    for j in i:
        if j==1:
            finals_test_MLP.append(ind)
        ind+=1
            
print(classification_report(finals_test_MLP, finals_pred_MLP, target_names=target_names))
print(accuracy_score(finals_test_MLP, finals_pred_MLP))
# Out:
# 271/271 [==============================] - 7s 26ms/step
#                         precision    recall  f1-score   support
#
#        Neural Networks       0.75      0.68      0.71        31
#             Case Based       0.83      0.89      0.86        38
# Reinforcement Learning       0.75      0.81      0.78        93
#  Probabilistic Methods       0.81      0.68      0.74        38
#     Genetic Algorithms       0.80      0.67      0.73        18
#          Rule Learning       0.87      0.76      0.81        17
#                 Theory       0.65      0.72      0.68        36
#
#              micro avg       0.76      0.76      0.76       271
#              macro avg       0.78      0.75      0.76       271
#           weighted avg       0.77      0.76      0.76       271
#
# 0.7638376383763837

# %%
def getTrainingData():
    i = 0
    lists = []
    labels = []
    maxi = 0
    for h in hyperedges:
        vertex_embedding_list = []
        hyperedge = hyperedges[h]
        for vertex in hyperedge["members"]:
            i+=1
            if i%100000==0:
                print(i)
            try: # Good ol' nondeterminism
                vertex_embedding_list.append(vertex_embeddings[vertex_ids.index(vertex)].tolist())
            except:
                print("Missed one: ",vertex)
        lists.append({"v":vertex_embedding_list})
        label = np.zeros((num_categories,))
        label[int(hyperedge["category"])-1] = 1
        labels.append(label)
    X_unshuffled = []
    
    for hlist in lists:
        np_vertex_embeddings = np.asarray(hlist["v"])
        x = np.zeros((vertex_embedding_dimension*max_groupsize,))
        i = 0        
        for embedding in np_vertex_embeddings:
            x[i*embedding.shape[0]:(i+1)*embedding.shape[0]] = embedding
            i+=1
        X_unshuffled.append(x)
    labels = np.asarray(labels)
    X_arr, Y_arr = shuffle(X_unshuffled, labels)
    X = np.asarray(X_arr)
    Y = np.asarray(Y_arr)
    return X, Y

X_deepset, Y_deepset = getTrainingData()

print(X_deepset.shape)
print(Y_deepset.shape)

# np.save(datadir+'/X_deepset_'+str(max_groupsize)+'.npy', X_deepset)
# np.save(datadir+'/Y_deepset_'+str(max_groupsize)+'.npy', Y_deepset)

from sklearn.model_selection import train_test_split
X_deepset_train, X_deepset_test, Y_deepset_train, Y_deepset_test = train_test_split(X_deepset, Y_deepset, train_size=0.9, test_size=0.1)
# Out:
# (2708, 2704)
# (2708, 7)

# %%
# %autoreload 2

from Models import DeepSets
from keras.callbacks import ModelCheckpoint, TensorBoard
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

dataset_name = "cora"
batch_size = 16
num_epochs = 10

deepsets_model = DeepSets(vertex_embedding_dimension=vertex_embedding_dimension,
                             max_hyperedge_size=max_groupsize,
                             num_outputs=num_categories,
                             dataset_name=dataset_name)
plot_model(deepsets_model, to_file='images/'+dataset_name+'_deepsets_model.png')
checkpointer = ModelCheckpoint(filepath='weights/'+dataset_name+'/deepsets_weights.hdf5', verbose=0, save_best_only=True)
tbCallBack = TensorBoard(log_dir='logs/'+dataset_name+'/deepsets_logs', histogram_freq=0, batch_size=batch_size, write_graph=True, write_grads=True, write_images=True, update_freq='batch')

history = deepsets_model.fit(X_deepset_train, Y_deepset_train, epochs=num_epochs, batch_size=batch_size,
        shuffle=True, validation_split=0.1,
        callbacks=[checkpointer,tbCallBack], verbose=1)
# Out:
# Train on 2193 samples, validate on 244 samples
# Epoch 1/10
# 2193/2193 [==============================] - 17s 8ms/step - loss: 1.6268 - mean_absolute_error: 0.2192 - categorical_accuracy: 0.3817 - f1_m: 0.0891 - val_loss: 1.1449 - val_mean_absolute_error: 0.1739 - val_categorical_accuracy: 0.6803 - val_f1_m: 0.4576
# Epoch 2/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.8812 - mean_absolute_error: 0.1323 - categorical_accuracy: 0.7031 - f1_m: 0.6525 - val_loss: 0.7518 - val_mean_absolute_error: 0.1050 - val_categorical_accuracy: 0.7541 - val_f1_m: 0.7606
# Epoch 3/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.6855 - mean_absolute_error: 0.0984 - categorical_accuracy: 0.7725 - f1_m: 0.7602 - val_loss: 0.6757 - val_mean_absolute_error: 0.0897 - val_categorical_accuracy: 0.7828 - val_f1_m: 0.7981
# Epoch 4/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.6139 - mean_absolute_error: 0.0865 - categorical_accuracy: 0.7975 - f1_m: 0.7920 - val_loss: 0.6992 - val_mean_absolute_error: 0.0960 - val_categorical_accuracy: 0.7500 - val_f1_m: 0.7527
# Epoch 5/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.5379 - mean_absolute_error: 0.0764 - categorical_accuracy: 0.8322 - f1_m: 0.8243 - val_loss: 0.6333 - val_mean_absolute_error: 0.0817 - val_categorical_accuracy: 0.7746 - val_f1_m: 0.7811
# Epoch 6/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.4786 - mean_absolute_error: 0.0687 - categorical_accuracy: 0.8445 - f1_m: 0.8496 - val_loss: 0.5976 - val_mean_absolute_error: 0.0799 - val_categorical_accuracy: 0.7910 - val_f1_m: 0.7840
# Epoch 7/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.4238 - mean_absolute_error: 0.0608 - categorical_accuracy: 0.8668 - f1_m: 0.8691 - val_loss: 0.8076 - val_mean_absolute_error: 0.0953 - val_categorical_accuracy: 0.7213 - val_f1_m: 0.7330
# Epoch 8/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.4338 - mean_absolute_error: 0.0628 - categorical_accuracy: 0.8600 - f1_m: 0.8606 - val_loss: 0.6280 - val_mean_absolute_error: 0.0732 - val_categorical_accuracy: 0.7992 - val_f1_m: 0.8132
# Epoch 9/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3598 - mean_absolute_error: 0.0523 - categorical_accuracy: 0.8865 - f1_m: 0.8799 - val_loss: 0.5945 - val_mean_absolute_error: 0.0733 - val_categorical_accuracy: 0.8156 - val_f1_m: 0.8114
# Epoch 10/10
# 2193/2193 [==============================] - 7s 3ms/step - loss: 0.3230 - mean_absolute_error: 0.0477 - categorical_accuracy: 0.8933 - f1_m: 0.8912 - val_loss: 0.6162 - val_mean_absolute_error: 0.0739 - val_categorical_accuracy: 0.7951 - val_f1_m: 0.7728

# %%
Y_pred_deepsets = deepsets_model.predict(X_deepset_test, batch_size=16, verbose=1)
finals_pred_deepsets = []
finals_test_deepsets = []
for p in Y_pred_deepsets:
    m = 0
    ind = 0
    final = 0
    for i in p:
        if i>m:
            m=i
            final=ind
        ind+=1
    finals_pred_deepsets.append(final)

for i in Y_deepset_test:
    ind=0
    for j in i:
        if j==1:
            finals_test_deepsets.append(ind)
        ind+=1
            
print(classification_report(finals_test_deepsets, finals_pred_deepsets, target_names=target_names))
print(accuracy_score(finals_test_deepsets, finals_pred_deepsets))
# Out:
# 271/271 [==============================] - 8s 28ms/step
#                         precision    recall  f1-score   support
#
#        Neural Networks       0.79      0.66      0.72        41
#             Case Based       0.88      0.90      0.89        40
# Reinforcement Learning       0.78      0.78      0.78        82
#  Probabilistic Methods       0.64      0.78      0.70        41
#     Genetic Algorithms       0.68      0.71      0.70        21
#          Rule Learning       0.69      0.73      0.71        15
#                 Theory       0.65      0.55      0.60        31
#
#              micro avg       0.75      0.75      0.75       271
#              macro avg       0.73      0.73      0.73       271
#           weighted avg       0.75      0.75      0.74       271
#
# 0.7453874538745388
